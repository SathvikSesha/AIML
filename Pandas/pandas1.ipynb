# %%
import pandas as pd

# %%
s = pd.Series([1,"Python",[1,2,4],{"name":"sathvik"},{2,2,3,4,5}]);
print(s)
print(type(s[3]))
print(s[3]['name'])
print([x**2 for x in s[2]])
# Out:
# 0                      1
# 1                 Python
# 2              [1, 2, 4]
# 3    {'name': 'sathvik'}
# 4           {2, 3, 4, 5}
# dtype: object
# <class 'dict'>
# sathvik
# [1, 4, 16]
